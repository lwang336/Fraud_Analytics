# %%
import pandas as pd
import numpy as np

start_time = pd.datetime.now()
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/Shared drives/DSO562 Fraud Project/NY property data.csv')

# %%
df["ZIP"].fillna(method ='ffill', inplace = True)

# %%
df_jenny = pd.read_csv('/content/drive/Shared drives/DSO562 Fraud Project/Fill_BLDFRONT_BLDDEPTH.csv')

# %%
df_yoki = pd.read_csv('/content/drive/Shared drives/DSO562 Fraud Project/fullvalstories.csv')

# %%
df_rory = pd.read_csv('/content/drive/Shared drives/DSO562 Fraud Project/Fill_avland_avtot.csv')

# %%
df_jennyw1 = pd.read_csv('/content/drive/Shared drives/DSO562 Fraud Project/Fill_ltfront.csv')

# %%
df_jennyw2 = pd.read_csv('/content/drive/Shared drives/DSO562 Fraud Project/Fill_LTDEPTH.csv')

# %%
ny = df.merge(df_jenny, how = "left", left_on = "RECORD", right_on = "RECORD")

# %%
df_yoki.drop("Unnamed: 0", axis = 1, inplace = True)

# %%
ny = ny.merge(df_yoki, how = "left", left_on = "RECORD", right_on = "RECORD")

# %%
ny = ny.merge(df_rory, how = "left", left_on = "RECORD", right_on = "RECORD")

# %%
ny = ny.merge(df_jennyw1, how = "left", left_on = "RECORD", right_on = "RECORD")

# %%
ny = ny = ny.merge(df_jennyw2, how = "left", left_on = "RECORD", right_on = "RECORD")

# %%
ny.head()
# Out:
#    RECORD        BBLE  B  ...  LTFRONT_y  Unnamed: 0_y LTDEPTH_y
# 0       1  1000010101  1  ...      500.0             0    1046.0
# 1       2  1000010201  1  ...       27.0             0     207.0
# 2       3  1000020001  1  ...      709.0             2     564.0
# 3       4  1000020023  1  ...      793.0             3     551.0
# 4       5  1000030001  1  ...      323.0             4    1260.0
#
# [5 rows x 44 columns]

# %%
ny = ny.drop(["BBLE","BLOCK","LOT","EASEMENT","OWNER","BLDGCL",
              "LTFRONT_x", "LTDEPTH_x","EXT","STORIES_x","BLDFRONT_x","BLDDEPTH_x",
              "FULLVAL_x","AVLAND_x","AVTOT_x","EXLAND","EXTOT","EXTOT", 
              "EXCD1", "STADDR", "EXMPTCL","AVLAND2", "AVTOT2", "EXLAND2", "EXTOT2",
              "EXCD2", "PERIOD", "YEAR", "VALTYPE","Unnamed: 0_x", "Unnamed: 0_y",
              "Unnamed: 0_x", "Unnamed: 0_y"], axis = 1)

# %%
ny.head()
# Out:
#    RECORD  B TAXCLASS      ZIP  ...      AVTOT_y     AVLAND_y  LTFRONT_y  LTDEPTH_y
# 0       1  1        4  10004.0  ...    9630000.0    4225500.0      500.0     1046.0
# 1       2  1        4  10004.0  ...   87210000.0   14310000.0       27.0      207.0
# 2       3  1        4  10004.0  ...   47108700.0   39008700.0      709.0      564.0
# 3       4  1        4  10004.0  ...   17640000.0   15255000.0      793.0      551.0
# 4       5  1        4  10004.0  ...  122535000.0  121050000.0      323.0     1260.0
#
# [5 rows x 12 columns]

# %%
ny.rename(columns = {'LTDEPTH_y':'LTDEPTH',
                     'BLDFRONT_y':'BLDFRONT',
                     'BLDDEPTH_y':'BLDDEPTH',
                     'STORIES_y':'STORIES',
                     'FULLVAL_y':'FULLVAL',
                     'AVTOT_y':'AVTOT',
                     'AVLAND_y':'AVLAND',
                     'LTFRONT_y':'LTFRONT'}, inplace = True)

# %%
ny.head()
# Out:
#    RECORD  B TAXCLASS      ZIP  ...        AVTOT       AVLAND  LTFRONT  LTDEPTH
# 0       1  1        4  10004.0  ...    9630000.0    4225500.0    500.0   1046.0
# 1       2  1        4  10004.0  ...   87210000.0   14310000.0     27.0    207.0
# 2       3  1        4  10004.0  ...   47108700.0   39008700.0    709.0    564.0
# 3       4  1        4  10004.0  ...   17640000.0   15255000.0    793.0    551.0
# 4       5  1        4  10004.0  ...  122535000.0  121050000.0    323.0   1260.0
#
# [5 rows x 12 columns]

# %%
ny.to_csv("/content/drive/Shared drives/DSO562 Fraud Project/NY_Group_code_1.csv")

# %%
ny.shape
# Out:
# (1070994, 12)

# %%
ny.isnull().sum()
# Out:
# RECORD      0
# B           0
# TAXCLASS    0
# ZIP         0
# BLDFRONT    0
# BLDDEPTH    0
# STORIES     0
# FULLVAL     0
# AVTOT       0
# AVLAND      0
# LTFRONT     0
# LTDEPTH     0
# dtype: int64
